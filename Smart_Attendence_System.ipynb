# %%
#data_csv_file
import pandas as pd
df=pd.read_csv("C:/Users/RIYA GUPTA/OneDrive/Documents/Book1.csv")
date=input("Enter date- dd/mm/yyyy")
df[date]='A' #add new column
df.to_csv("C:/Users/RIYA GUPTA/OneDrive/Documents/Book1.csv",index=False)
df
# Out:
# Enter date- dd/mm/yyyy02/04/2023
#    ID 01/04/2023        Name 02/04/2023
# 0   1          P  Riya Gupta          A
# 1   2          P      Babita          A

# %%
#to take id,name along with pic capture
import pandas as pd
import cv2
df=pd.read_csv("C:/Users/RIYA GUPTA/OneDrive/Documents/Book1.csv")
cam=cv2.VideoCapture(0)
detector=cv2.CascadeClassifier('C:/Users/RIYA GUPTA/Downloads/haarcascade_frontalface_default.xml')
ID=input("enter your id: ")
Name=input("enter the name: ")
df2=pd.DataFrame({"ID":[ID],"Name":[Name]})
df=pd.concat([df,df2]).drop_duplicates().reset_index(drop=True)
df.to_csv("C:/Users/RIYA GUPTA/OneDrive/Documents/Book1.csv",index=False)
samplenum=0
sampleNum=0
while True:
    ret,img=cam.read()
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=detector.detectMultiScale(gray,1.1,4)
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(144,1,1),2)
        #incrementing sampleNum
        sampleNum=sampleNum+1
        #saving the captured face in folder
        cv2.imwrite("C:/Users/RIYA GUPTA/OneDrive/Desktop/my pic/user."+ID+'.'+str(sampleNum)+".jpg",gray[y:y+h,x:x+w])
        cv2.imshow('frame',img)
    if cv2.waitKey(100) & 0xFF==ord('q'):  #wait for 100 milliseconds
        break
    elif sampleNum>10:
        break
cam.release()
cv2.destroyAllWindows()
# Out:
# enter your id: 2
# enter the name: Babita

# %%
#train data
import cv2
import os
import numpy as np
from PIL import Image

recognizer=cv2.face.LBPHFaceRecognizer_create()
path='C:/Users/RIYA GUPTA/OneDrive/Desktop/my pic'

def getImagesWithID(path):
    imagePaths=[os.path.join(path,f) for f in os.listdir(path)]
    faces=[]
    IDs=[]
    for imagePath in imagePaths:
        faceImg=Image.open(imagePath).convert('L')
        faceNp=np.array(faceImg,'uint8')
        ID=int(os.path.split(imagePath)[-1].split('.')[1])
        faces.append(faceNp)
        IDs.append(ID)

        cv2.imshow("training",faceNp)
        cv2.waitKey(100) # for 10 milliseconds wait......
    return np.array(IDs), faces

Ids, faces=getImagesWithID(path)
recognizer.train(faces,np.array(Ids))
recognizer.save('C:/Users/RIYA GUPTA/Downloads/trainningData.yml')
cv2.destroyAllWindows()

# %%
#taking attendence online
import cv2
import numpy as np
import pandas as pd
date=input('Enter date- dd/mm/yyyy: ')
faceDetect=cv2.CascadeClassifier('C:/Users/RIYA GUPTA/Downloads/haarcascade_frontalface_default.xml')
cam=cv2.VideoCapture(0)
rec=cv2.face.LBPHFaceRecognizer_create()
rec.read('C:/Users/RIYA GUPTA/Downloads/trainningData.yml')
id=0
font=cv2.FONT_HERSHEY_COMPLEX_SMALL
df=pd.read_csv("C:/Users/RIYA GUPTA/OneDrive/Documents/Book1.csv")
while True:
    ret,img=cam.read()
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=detector.detectMultiScale(gray,1.1,4)
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(144,1,1),2)
        id,conf=rec.predict(gray[y:y+h,x:x+w])
        id1=df['Name'][df.ID==id]
        df[date][df.ID==id]='P'
        df.to_csv("C:/Users/RIYA GUPTA/OneDrive/Documents/Book1.csv",index=False)
        cv2.putText(img,str(id1),(x,y+h),font,3,255)
    cv2.imshow('Face',img)
    if(cv2.waitKey(1) & 0xFF==ord('q')):
        break
cam.release()
cv2.destroyAllWindows()
# Out:
# Enter date- dd/mm/yyyy: 01/04/2023
# <ipython-input-7-49750b3c8cc6>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[date][df.ID==id]='P'
# <ipython-input-7-49750b3c8cc6>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[date][df.ID==id]='P'
# <ipython-input-7-49750b3c8cc6>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[date][df.ID==id]='P'
# <ipython-input-7-49750b3c8cc6>:21: SettingWithCopyWarning:
# ...
